# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Stations, Daily

# %%
# Get weather stations ordered by distance to Vancouver, BC
stations = Stations()
# Fetch closest station (limit = 1)
stations = stations.nearby(31.9686 , -99.9018)
stations = stations.region('US','TX')
station = stations.fetch(1000)
station
# Out:
#                                   name country region    wmo  icao  latitude  \
# id
# KCOM0                          Coleman      US     TX   <NA>  KCOM   31.8411
# 69019                    Abilene / Tye      US     TX  69019  KDYS   32.4198
# 72266         Abilene Regional Airport      US     TX  72266  KABI   32.4167
# KSWW0     Sweetwater / Avenger Village      US     TX   <NA>  KSWW   32.4674
# 72263                     Mathis Field      US     TX  72263  KSJT   31.3500
# ...                                ...     ...    ...    ...   ...       ...
# KHRL0  Harlingen / Santa Elena Colonia      US     TX   <NA>  KHRL   26.2285
# KPIL0        Port Isabel / Holly Beach      US     TX   <NA>  KPIL   26.1662
# KSPL0               South Padre Island      US     TX   <NA>  KSPL   26.0700
# 72250       Brownsville/South Padre Is      US     TX  72250  KBRO   25.9000
# KHCA0          Big Spring / Holy Cross      US     TX   <NA>  KHCA   62.1883
#
# ...

# %%
# Get daily data for 2018 at the selected weather station
data = Daily(station, start = datetime(2010, 1, 1), end = datetime(2022, 2, 28))
# Fetch Pandas DataFrame
data = data.fetch()

# %%
# Plot line chart including average, minimum and maximum temperature
data.plot(y = ['tavg', 'tmin', 'tmax'], kind = 'line')
# Show chart
plt.show()

# %%
data.to_csv('weather_data/texas_weather_historical.csv')
