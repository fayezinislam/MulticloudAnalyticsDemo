# %% [markdown]
# # Energy Stock Price Movements
#
# Using information from [EIA](https://www.eia.gov/) we will determine if monitoring changes in cash market power prices have a strong relationship with the price of energy sector stocks.
#
# This can become the foundation for a variety of use cases within the functions of an exchange, clearing house, trading firm, or compliance:

# %%
import pandas as pd
from google.cloud import bigquery
import numpy as np
import matplotlib.pyplot as plt

# %%
client = bigquery.Client()#location="US")
print("Client creating using default project: {}".format(client.project))
# Out:
# Client creating using default project: fsi-select-demo

# %% [markdown]
# ## Query Trade Data on NRG Stream   [$NRG:NDAQ](https://www.nasdaq.com/market-activity/stocks/nrg)
#
# Ask BigQuery for T&S Data aggregated on a monthly trade weighted price.  Data is located on AWS.  BQ automatically knows where to look based upon my query and returns it without concern for where it came.
#
# Source: BigQuery
#
# Destination: Python Pandas Dataframe (tradesDF)

# %%
query = """
    SELECT timestamp_trunc(timestamp, month) as date, 
    symbol, 
    sum(trade_size) as total_volume, 
    sum(trade_price * trade_size)/ sum(trade_size) as average_trade_price 
    FROM `fsi-select-demo.POLYGON.TRADES_WITH_ISSUER` 
    WHERE trade_size <> 0
    AND date(timestamp) >= '2013-01-01'
    AND symbol='NRG'
    group by timestamp_trunc(timestamp, month), symbol;
    """
query_job = client.query(
    query,
    location="US",
)  

#load to Pandas DataFrame
tradesDF = query_job.to_dataframe()
tradesDF.set_index('date', inplace=True)
tradesDF.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f9d02999d1c4> in <module>
#      16
#      17 #load to Pandas DataFrame
# ---> 18 tradesDF = query_job.to_dataframe()
#      19 tradesDF.set_index('date', inplace=True)
#      20 tradesDF.head()
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, date_as_object)
#    1344             progress_bar_type=progress_bar_type,
#    1345             create_bqstorage_client=create_bqstorage_client,
# -> 1346             date_as_object=date_as_object,
#    1347         )
#    1348
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/table.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, date_as_object)
#    1865             progress_bar_type=progress_bar_type,
#    1866             bqstorage_client=bqstorage_client,
# -> 1867             create_bqstorage_client=create_bqstorage_client,
#    1868         )
#    1869
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/table.py in to_arrow(self, progress_bar_type, bqstorage_client, create_bqstorage_client)
#    1668         owns_bqstorage_client = False
#    1669         if not bqstorage_client and create_bqstorage_client:
# -> 1670             bqstorage_client = self.client._ensure_bqstorage_client()
#    1671             owns_bqstorage_client = bqstorage_client is not None
#    1672
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py in _ensure_bqstorage_client(self, bqstorage_client, client_options, client_info)
#     507                 credentials=self._credentials,
#     508                 client_options=client_options,
# --> 509                 client_info=client_info,
#     510             )
#     511
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery_storage_v1/services/big_query_read/client.py in __init__(self, credentials, transport, client_options, client_info)
#     282                 ssl_channel_credentials=ssl_credentials,
#     283                 quota_project_id=client_options.quota_project_id,
# --> 284                 client_info=client_info,
#     285             )
#     286
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery_storage_v1/services/big_query_read/transports/grpc.py in __init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, quota_project_id, client_info)
#     162                 ssl_credentials=ssl_channel_credentials,
#     163                 scopes=scopes or self.AUTH_SCOPES,
# --> 164                 quota_project_id=quota_project_id,
#     165             )
#     166
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery_storage_v1/services/big_query_read/transports/grpc.py in create_channel(cls, host, credentials, credentials_file, scopes, quota_project_id, **kwargs)
#     219             scopes=scopes,
#     220             quota_project_id=quota_project_id,
# --> 221             **kwargs,
#     222         )
#     223
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/grpc_helpers.py in create_channel(target, credentials, scopes, ssl_credentials, credentials_file, quota_project_id, default_scopes, default_host, **kwargs)
#     307         ssl_credentials=ssl_credentials,
#     308         quota_project_id=quota_project_id,
# --> 309         default_host=default_host,
#     310     )
#     311
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/grpc_helpers.py in _create_composite_credentials(credentials, credentials_file, default_scopes, scopes, ssl_credentials, quota_project_id, default_host)
#     231     elif credentials:
#     232         credentials = google.auth.credentials.with_scopes_if_required(
# --> 233             credentials, scopes=scopes, default_scopes=default_scopes
#     234         )
#     235     else:
#
# TypeError: with_scopes_if_required() got an unexpected keyword argument 'default_scopes'

# %%
query = "select * FROM `fsi-select-demo.bq_omni_staging_s3.TRADES_NRG` WHERE DATE(timestamp) = '2013-04-11'"
query_job = client.query(
    query,
    location="aws-us-east-1",
)  

tradesDF = query_job.to_dataframe()

# %% [markdown]
# ## Trade Price History Visualizations
#
# - Do I have the data I need?
# - Should I normalize it (e.g. log return)
# - Should I smooth it via resampling?

# %%
#create column simple return
tradesDF['simple_rtn'] = tradesDF.average_trade_price.pct_change()
#create column logrithmic returns
tradesDF['log_rtn'] = np.log(tradesDF.average_trade_price/tradesDF.average_trade_price.shift(1))
#plot
tradesDF[['average_trade_price','log_rtn','total_volume']].plot(subplots=True, figsize=(15,6))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>], dtype=object)

# %%
#Resample Plots (3months)
tradesDF[['average_trade_price','log_rtn','total_volume']].resample("3m").median().plot(subplots=True, figsize=(15,6))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>], dtype=object)

# %% [markdown]
# ## Understand Retail Power Pricing in Texas
#
# Leveraging my prior work to load US EIA Data, Ask BigQuery for Power Price data.  Data is located on Google Cloud.  BQ automatically knows where to look based upon my query and returns it without concern for where it came.
#
# Source: BigQuery
#
# Destination: Python Pandas Dataframe (powerpricingDF)

# %%
query = """
    SELECT date, state, commercial, industrial, residential 
    FROM `fsi-select-demo.us_eia.electricity_retail_pricing_type` 
    WHERE state = 'Texas'
    AND date >= '2013-01-01' -- Natural Date Parsing!
    AND date <= %s""" % "'"+tradesDF.index.max().date().strftime('%Y-%m-%d')+"'"  #Pass in max from trades infromation.
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query
powerpricingDF = query_job.to_dataframe()

powerpricingDF.set_index('date', inplace=True)
powerpricingDF.head()

# %% [markdown]
# ## Price History Visualizations
#
# - Do I have the data I need?
# - Should I normalize it?
# - Should I smooth it via resampling?
# - What are other statistical facts like correlation?

# %%
powerpricingDF.plot(subplots=True, figsize=(15,6))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>], dtype=object)

# %%
powerpricingDF.corr()
# Out:
#              commercial  industrial  residential
# commercial     1.000000   -0.117991    -0.087944
# industrial    -0.117991    1.000000     0.612532
# residential   -0.087944    0.612532     1.000000

# %% [markdown]
# # Join Data Sets
#
# Are there connections between the retail power prices in Texas and the overall performance / price of NRG?

# %%
joinedDF = pd.merge(tradesDF[['symbol','average_trade_price']], powerpricingDF, left_index=True, right_index=True)
joinedDF.plot(subplots=True, figsize=(15,10))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>],
#       dtype=object)

# %% [markdown]
# ## Trade Price and Cash Market Price Correlations
#
# Yes; look at the industrial and residential prices versus the stock price. Residential has a 0.50 R<sup>2</sup>.

# %%
# Correlation (All)
joinedDF.corr()
# Out:
#                      average_trade_price  commercial  industrial  residential
# average_trade_price             1.000000   -0.226841    0.396888     0.503035
# commercial                     -0.226841    1.000000   -0.117991    -0.087944
# industrial                      0.396888   -0.117991    1.000000     0.612532
# residential                     0.503035   -0.087944    0.612532     1.000000

# %% [markdown]
# # Residential Power Prices to NRG Monthly Stock Prices Rolling Periods
#
# Correlations from 2013 to present show a strong relationship. How does that look over rolling periods.  This will become the foundation for a larger strategy on risk managment, reporting, and monitoring various price movements in NRG. I will need to source a realtime price feed from [ERCOT](http://www.ercot.com/mktinfo/rtm)

# %%
#Rolling Correlation 3, 6, 9, 12 month
fig, ax = plt.subplots()

joinedDF['average_trade_price'].rolling(3).corr(joinedDF['residential']).plot(kind='hist', figsize=(15,6), legend=True)
joinedDF['average_trade_price'].rolling(6).corr(joinedDF['residential']).plot(kind='hist', figsize=(15,6), legend=True)
joinedDF['average_trade_price'].rolling(9).corr(joinedDF['residential']).plot(kind='hist', figsize=(15,6), legend=True)
joinedDF['average_trade_price'].rolling(12).corr(joinedDF['residential']).plot(kind='hist', figsize=(15,6), legend=True)
joinedDF['average_trade_price'].rolling(18).corr(joinedDF['residential']).plot(kind='hist', figsize=(15,6), legend=True)

ax.legend(["3M", "6M",'9M','12M','18M'])
